# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.prettify()[:1000])
table = soup.find('table') 
if table:

    headers = [header.text.strip() for header in table.find_all('th')]
    rows = table.find_all('tr')[1:]  # Skip the header row

    data = []
    for row in rows:
        columns = row.find_all('td')
        data.append([col.text.strip() for col in columns])

    gme_revenue_df = pd.DataFrame(data, columns=headers)

    print(gme_revenue_df.tail())
else:
    print("Table not found.")
# Out:
# <html>
#  <head>
#  </head>
#  <body>
#   <div style="margin: 50px auto; width: 50%; border: 1px solid #dfdfdf; padding: 20px 50px 30px 50px; font-family:helvetica;">
#    <h1>
#     We do not allow automated access to our servers.
#    </h1>
#    <h2>
#     <p>
#      Automated access to our data is prohibited by our data provider.
#     </p>
#     <p>
#      If you are a user attempting to access the site via a browser, please follow this process to regain access:
#     </p>
#     <ul>
#      <li>
#       Go to
#       <a href="https://whatismyipaddress.com/" rel="noopener noreferrer" target="_blank">
#        whatismyipaddress
#       </a>
#       and obtain your IPv4 address
#      </li>
#      <li>
#       Email us your IPv4 address at
#       <a class="__cf_email__" data-cfemail="4821262e270825292b3a273c3a2d262c3b66262d3c" href="/cdn-cgi/l/email-protection">
#        [email protected]
#       </a>
#      </li>
#      <li>
# ...

# %%
import pandas as pd

# Data for annual revenue
annual_revenue_data = {
    'Year': [2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009],
    'Revenue (Millions of US $)': [5273, 5927, 6011, 5090, 6466, 8285, 8547, 7965, 9364, 9296, 9040, 8887, 9551, 9474, 9078, 8806]
}

# Create DataFrame
annual_revenue_df = pd.DataFrame(annual_revenue_data)
print(annual_revenue_df)
# Out:
#     Year  Revenue (Millions of US $)
# 0   2024                        5273
# 1   2023                        5927
# 2   2022                        6011
# 3   2021                        5090
# 4   2020                        6466
# 5   2019                        8285
# 6   2018                        8547
# 7   2017                        7965
# 8   2016                        9364
# 9   2015                        9296
# 10  2014                        9040
# 11  2013                        8887
# 12  2012                        9551
# 13  2011                        9474
# 14  2010                        9078
# 15  2009                        8806

# %%
# Data for quarterly revenue
quarterly_revenue_data = {
    'Date': [
        '2024-04-30', '2024-01-31', '2023-10-31', '2023-07-31', '2023-04-30', '2023-01-31',
        '2022-10-31', '2022-07-31', '2022-04-30', '2022-01-31', '2021-10-31', '2021-07-31',
        '2021-04-30', '2021-01-31', '2020-10-31', '2020-07-31', '2020-04-30', '2020-01-31',
        '2019-10-31', '2019-07-31', '2019-04-30', '2019-01-31', '2018-10-31', '2018-07-31',
        '2018-04-30', '2018-01-31', '2017-10-31', '2017-07-31', '2017-04-30', '2017-01-31',
        '2016-10-31', '2016-07-31', '2016-04-30', '2016-01-31', '2015-10-31', '2015-07-31',
        '2015-04-30', '2015-01-31', '2014-10-31', '2014-07-31', '2014-04-30', '2014-01-31',
        '2013-10-31', '2013-07-31', '2013-04-30', '2013-01-31', '2012-10-31', '2012-07-31',
        '2012-04-30', '2012-01-31', '2011-10-31', '2011-07-31', '2011-04-30', '2011-01-31',
        '2010-10-31', '2010-07-31', '2010-04-30', '2010-01-31', '2009-10-31', '2009-07-31',
        '2009-04-30', '2009-01-31'
    ],
    'Revenue (Millions of US $)': [
        882, 1794, 1078, 1164, 1237, 2226, 1186, 1136, 1378, 2254, 1297, 1183, 1277, 2122, 
        1005, 942, 1021, 2194, 1439, 1286, 1548, 3063, 1935, 1501, 1786, 2825, 1989, 1688, 
        2046, 2403, 1959, 1632, 1972, 3525, 2016, 1762, 2061, 3476, 2092, 1731, 1996, 3684, 
        2107, 1384, 1865, 3562, 1773, 1550, 2002, 3579, 1947, 1744, 2281, 3693, 1899, 1799, 
        2083, 3524, 1835, 1739, 1981, 3492
    ]
}

# Create DataFrame
quarterly_revenue_df = pd.DataFrame(quarterly_revenue_data)
print(quarterly_revenue_df)
# Out:
#           Date  Revenue (Millions of US $)
# 0   2024-04-30                         882
# 1   2024-01-31                        1794
# 2   2023-10-31                        1078
# 3   2023-07-31                        1164
# 4   2023-04-30                        1237
# ..         ...                         ...
# 57  2010-01-31                        3524
# 58  2009-10-31                        1835
# 59  2009-07-31                        1739
# 60  2009-04-30                        1981
# 61  2009-01-31                        3492
#
# [62 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
annual_revenue_df = pd.DataFrame(annual_revenue_data)
quarterly_revenue_df = pd.DataFrame(quarterly_revenue_data)
plt.figure(figsize=(12, 6))
sns.barplot(data=annual_revenue_df, x='Year', y='Revenue (Millions of US $)', palette='viridis')
plt.title('GameStop Annual Revenue')
plt.xlabel('Year')
plt.ylabel('Revenue (Millions of US $)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

quarterly_revenue_df['Date'] = pd.to_datetime(quarterly_revenue_df['Date'])

plt.figure(figsize=(14, 7))
sns.barplot(data=quarterly_revenue_df, x='Date', y='Revenue (Millions of US $)', palette='viridis')
plt.title('GameStop Quarterly Revenue')
plt.xlabel('Date')
plt.ylabel('Revenue (Millions of US $)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\palla\AppData\Local\Temp\ipykernel_23520\2044746799.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=annual_revenue_df, x='Year', y='Revenue (Millions of US $)', palette='viridis')
# C:\Users\palla\AppData\Local\Temp\ipykernel_23520\2044746799.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=quarterly_revenue_df, x='Date', y='Revenue (Millions of US $)', palette='viridis')

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url ='https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.prettify()[:1000])
table = soup.find('table') 
if table:

    headers = [header.text.strip() for header in table.find_all('th')]
    rows = table.find_all('tr')[1:]  # Skip the header row

    data = []
    for row in rows:
        columns = row.find_all('td')
        data.append([col.text.strip() for col in columns])

    gme_revenue_df = pd.DataFrame(data, columns=headers)

    print(gme_revenue_df.tail())
else:
    print("Table not found.")
# Out:
# <html>
#  <head>
#  </head>
#  <body>
#   <div style="margin: 50px auto; width: 50%; border: 1px solid #dfdfdf; padding: 20px 50px 30px 50px; font-family:helvetica;">
#    <h1>
#     We do not allow automated access to our servers.
#    </h1>
#    <h2>
#     <p>
#      Automated access to our data is prohibited by our data provider.
#     </p>
#     <p>
#      If you are a user attempting to access the site via a browser, please follow this process to regain access:
#     </p>
#     <ul>
#      <li>
#       Go to
#       <a href="https://whatismyipaddress.com/" rel="noopener noreferrer" target="_blank">
#        whatismyipaddress
#       </a>
#       and obtain your IPv4 address
#      </li>
#      <li>
#       Email us your IPv4 address at
#       <a class="__cf_email__" data-cfemail="4821262e270825292b3a273c3a2d262c3b66262d3c" href="/cdn-cgi/l/email-protection">
#        [email protected]
#       </a>
#      </li>
#      <li>
# ...

# %%
import pandas as pd

# Annual revenue data for Tesla
annual_revenue_data = {
    'Year': [2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009],
    'Revenue (Millions of US $)': [96773, 81462, 53823, 31536, 24578, 21461, 11759, 7000, 4046, 3198, 2013, 413, 204, 117, 112]
}

annual_revenue_df = pd.DataFrame(annual_revenue_data)

# Quarterly revenue data for Tesla
quarterly_revenue_data = {
    'Date': [
        '2024-03-31', '2023-12-31', '2023-09-30', '2023-06-30', '2023-03-31',
        '2022-12-31', '2022-09-30', '2022-06-30', '2022-03-31', '2021-12-31',
        '2021-09-30', '2021-06-30', '2021-03-31', '2020-12-31', '2020-09-30',
        '2020-06-30', '2020-03-31', '2019-12-31', '2019-09-30', '2019-06-30',
        '2019-03-31', '2018-12-31', '2018-09-30', '2018-06-30', '2018-03-31',
        '2017-12-31', '2017-09-30', '2017-06-30', '2017-03-31', '2016-12-31',
        '2016-09-30', '2016-06-30', '2016-03-31', '2015-12-31', '2015-09-30',
        '2015-06-30', '2015-03-31', '2014-12-31', '2014-09-30', '2014-06-30',
        '2014-03-31', '2013-12-31', '2013-09-30', '2013-06-30', '2013-03-31',
        '2012-12-31', '2012-09-30', '2012-06-30', '2012-03-31', '2011-12-31',
        '2011-09-30', '2011-06-30', '2011-03-31', '2010-12-31', '2010-09-30',
        '2010-06-30', '2010-03-31', '2009-12-31', '2009-09-30', '2009-06-30'
    ],
    'Revenue (Millions of US $)': [
        21301, 25167, 23350, 24927, 23329, 24318, 21454, 16934, 18756, 17719,
        13757, 11958, 10389, 10744, 8771, 6036, 5985, 7384, 6303, 6350, 4541,
        7226, 6824, 4002, 3409, 3288, 2985, 2790, 2696, 2285, 2298, 1270, 1147,
        1214, 937, 955, 940, 957, 852, 769, 621, 615, 431, 405, 562, 306, 50,
        27, 30, 39, 58, 58, 49, 36, 31, 28, 21, None, 46, 27
    ]
}

annual_revenue_df = pd.DataFrame(annual_revenue_data)
quarterly_revenue_df = pd.DataFrame(quarterly_revenue_data)

# Display DataFrames to verify
print("Annual Revenue Data:")
print(annual_revenue_df)

print("\nQuarterly Revenue Data:")
print(quarterly_revenue_df)
# Out:
# Annual Revenue Data:
#     Year  Revenue (Millions of US $)
# 0   2023                       96773
# 1   2022                       81462
# 2   2021                       53823
# 3   2020                       31536
# 4   2019                       24578
# 5   2018                       21461
# 6   2017                       11759
# 7   2016                        7000
# 8   2015                        4046
# 9   2014                        3198
# 10  2013                        2013
# 11  2012                         413
# 12  2011                         204
# 13  2010                         117
# 14  2009                         112
#
# Quarterly Revenue Data:
#           Date  Revenue (Millions of US $)
# 0   2024-03-31                     21301.0
# 1   2023-12-31                     25167.0
# 2   2023-09-30                     23350.0
# 3   2023-06-30                     24927.0
# 4   2023-03-31                     23329.0
# 5   2022-12-31                     24318.0
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.bar(annual_revenue_df['Year'].astype(str), annual_revenue_df['Revenue (Millions of US $)'], color='teal')
plt.xlabel('Year')
plt.ylabel('Revenue (Millions of US $)')
plt.title('Tesla Annual Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('tesla_annual_revenue.png')  
plt.show()

plt.figure(figsize=(12, 6))
quarterly_revenue_df['Date'] = pd.to_datetime(quarterly_revenue_df['Date'])
plt.plot(quarterly_revenue_df['Date'], quarterly_revenue_df['Revenue (Millions of US $)'], marker='o', linestyle='-', color='blue')
plt.xlabel('Date')
plt.ylabel('Revenue (Millions of US $)')
plt.title('Tesla Quarterly Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('tesla_quarterly_revenue.png') 
plt.show()
